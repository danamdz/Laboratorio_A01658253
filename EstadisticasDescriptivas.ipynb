# %% [markdown]
# <a href="https://colab.research.google.com/github/danamdz/Laboratorio_A01658253/blob/main/EstadisticasDescriptivas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Carga los datos usando tu lector de csv o con pandas. Es recomendable hacerlo con pandas.

# %%
import numpy as np
import pandas as pd

aguacate = pd.read_csv("avocado.csv")
aguacate.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7           7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8           8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9           9  2015-10-25          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# ...

# %% [markdown]
# * Verifica la cantidad de datos que tienes, las variables que contiene cada vector de datos e identifica el tipo de variables.
# * Analiza las variables para saber que representa cada una y en que rangos se encuentran. Si la descripción del problema no te lo indica, utiliza el máximo y el mínimo para encontrarlo.
# * Basándose en la media, mediana y desviación estándar de cada variable, que conclusiones puedes entregar de los datos.

# %%
print(aguacate.shape)
print(("-"*20+"\n")*3)
display(aguacate.info())
print(("-"*20+"\n")*3)
display(aguacate.describe())
# Out:
# (18249, 14)
# --------------------
# --------------------
# --------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB
# None
# ...

# %% [markdown]
# 1. El conjunto de datos contiene 9 columnas que contienen números con punto decimal (flotantes), 2 columnas con números enteros y 3 columnas con texto (cadenas de caracteres).
#
# 2. Cuando se trabaja con las columnas que contienen datos numéricos, se puede realizar un análisis detallado. En particular, se menciona el uso del método "describe()", que proporciona información importante como los valores mínimo y máximo, la media, la mediana (que se conoce como percentil 50%), el primer cuartil (percentil 25%), el tercer cuartil (percentil 75%) y la desviación estándar. Estas estadísticas son útiles para comprender la distribución y las características de los datos numéricos.
#
# 3. Las columnas de tipo cadena de caracteres (texto) ofrecen la oportunidad de categorizar y segmentar los datos. Se mencionan ejemplos de cómo se pueden utilizar, como agrupar datos por región o fecha. Esto sugiere que estas columnas pueden usarse para organizar y analizar los datos de manera más específica.
#
# 4. En cuanto a las conclusiones del análisis, se indica que los productos más vendidos son las bolsas pequeñas, seguidas de las bolsas grandes y, por último, las bolsas extra grandes. Esto sugiere una jerarquía o clasificación basada en las ventas de productos específicos dentro del conjunto de datos.
